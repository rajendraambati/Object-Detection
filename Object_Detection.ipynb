# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.2/881.2 kB 19.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Define paths
dataset_path = '/content/drive/MyDrive/YOLOv8_Dataset'
train_images_path = f'{dataset_path}/images/train'
val_images_path = f'{dataset_path}/images/val'
test_images_path = f'{dataset_path}/images/test'
train_labels_path = f'{dataset_path}/labels/train'
val_labels_path = f'{dataset_path}/labels/val'
test_images_path = f'{dataset_path}/images/test'

# %%
data_yml="""
train: /content/drive/MyDrive/YOLOv8_Dataset/images/train
val: /content/drive/MyDrive/YOLOv8_Dataset/images/valid
test: /content/drive/MyDrive/YOLOv8_Dataset/images/test
nc: 5
names: ['Ambulance', 'Bus', 'Car', 'Motorcycle', 'Truck']
"""

# %%
data_yml
# Out:
# "\ntrain: /content/drive/MyDrive/YOLOv8_Dataset/images/train\nval: /content/drive/MyDrive/YOLOv8_Dataset/images/valid\ntest: /content/drive/MyDrive/YOLOv8_Dataset/images/test\nnc: 5\nnames: ['Ambulance', 'Bus', 'Car', 'Motorcycle', 'Truck']\n"

# %%
with open('data.yaml', 'w') as f:
  f.write(data_yml)

# %%
# !pip install ultralytics

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.28 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.3/112.6 GB disk)

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=data.yaml epochs=300 imgsz=640 batch=16 plots=True
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 121MB/s]
# Ultralytics 8.3.28 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model=runs/detect/train/weights/best.pt data=data.yaml
# Out:
# Ultralytics 8.3.28 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,842,655 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/drive/MyDrive/YOLOv8_Dataset/labels/valid.cache... 250 images, 0 backgrounds, 0 corrupt: 100% 250/250 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:08<00:00,  1.86it/s]
#                    all        250        454       0.64      0.568      0.588      0.442
#              Ambulance         50         64       0.73      0.875      0.865      0.737
#                    Bus         30         46      0.739      0.616      0.723      0.582
#                    Car         90        238      0.618      0.407      0.456      0.328
#             Motorcycle         42         46      0.625      0.609      0.537      0.299
#                  Truck         38         60      0.488      0.333      0.359      0.263
# ...

# %%
from ultralytics import YOLO

model = YOLO('runs/detect/train/weights/best.pt')
res=model.predict(
   source='motor.jpg',
   conf=0.80,
   save=True
)
for result in res:

    result.boxes.xyxy   # box with xyxy format, (N, 4)
    result.boxes.xywh   # box with xywh format, (N, 4)
    result.boxes.xyxyn  # box with xyxy format but normalized, (N, 4)
    result.boxes.xywhn  # box with xywh format but normalized, (N, 4)
    result.boxes.conf   # confidence score, (N, 1)
    result.boxes.cls    # cls, (N, 1)
# Out:
# image 1/1 /content/motor.jpg: 512x640 (no detections), 64.3ms
# Speed: 4.3ms preprocess, 64.3ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to runs/detect/predict5
